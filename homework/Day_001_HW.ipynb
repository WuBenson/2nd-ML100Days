# %% [markdown]
# # HW1
#
# Dataset ：
# [League of Legends Competitive matches, 2015 to 2018](https://www.kaggle.com/chuckephron/leagueoflegends)
#
# 1. 你選的這組資料為何重要?
#
#  + 英雄聯盟等電競運動興起，如果能用這些數據做分析去預測勝利的一方，與當季遊戲改動的版本與玩家適應的變化等，我覺得能夠增加電競產業更多的發展性。
#
#
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
#
#  + Kaggle的資料集，由Riot官方，透過定期舉辦季後賽，冠軍賽來蒐集每個區域的選手資料。
#
#
# 3. 蒐集而來的資料型態為何
#
#  + String, numeric
#
#
# 4. 這組資料想解決的問題如何評估
#
#  + 想預測勝利的一方
#
# # HW2
#
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
#
#  + 對我來說，提升業績是顧客是否會推薦給其他人，與是否會時常使用。
#
#
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
#
#  + 資料可以透過製作手機App來取得使用者的數據。
#
#
# 3. 蒐集而來的資料型態為何
#
#  + json格式， String , numeric
#
#
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
#
#  + 透過使用者線上叫車的服務分析族群分布，並統計每月會員成長幅度。
#
#
# # HW3

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
def mean_absolute_error(y, yp):

    return sum(abs(y - yp)) / len(y)
    
MAE = mean_absolute_error(y, y_hat)
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean absolute error is 11.226

# %% [markdown]
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $

# %%
def MSE(y, yp):
    return sum((y - yp)*(y - yp)) / len(y)

mse = MSE(y, y_hat)
print("The Mean absolute error is %.3f" % (mse))
# Out:
# The Mean absolute error is 194.040
